# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/heart.csv')

# %% [markdown]
# **Data Info**

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
df['thal'].unique()
# Out:
# array([3, 2, 1, 0])

# %% [markdown]
# # **Data Encoding**

# %%
categorical_col=['cp','restecg','slope','ca','thal']
df_encoded=pd.get_dummies(df,columns=categorical_col,drop_first=False,)

# %%
df_encoded
# Out:
#       age  sex  trestbps  chol  fbs  thalach  exang  oldpeak  target   cp_0  \
# 0      52    1       125   212    0      168      0      1.0       0   True
# 1      53    1       140   203    1      155      1      3.1       0   True
# 2      70    1       145   174    0      125      1      2.6       0   True
# 3      61    1       148   203    0      161      0      0.0       0   True
# 4      62    0       138   294    1      106      0      1.9       0   True
# ...   ...  ...       ...   ...  ...      ...    ...      ...     ...    ...
# 1020   59    1       140   221    0      164      1      0.0       1  False
# 1021   60    1       125   258    0      141      1      2.8       0   True
# 1022   47    1       110   275    0      118      1      1.0       0   True
# 1023   50    0       110   254    0      159      0      0.0       1   True
# 1024   54    1       120   188    0      113      0      1.4       0   True
#
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        1025 non-null   int64
#  1   sex        1025 non-null   int64
#  2   trestbps   1025 non-null   int64
#  3   chol       1025 non-null   int64
#  4   fbs        1025 non-null   int64
#  5   thalach    1025 non-null   int64
#  6   exang      1025 non-null   int64
#  7   oldpeak    1025 non-null   float64
#  8   target     1025 non-null   int64
#  9   cp_0       1025 non-null   bool
#  10  cp_1       1025 non-null   bool
#  11  cp_2       1025 non-null   bool
#  12  cp_3       1025 non-null   bool
#  13  restecg_0  1025 non-null   bool
#  14  restecg_1  1025 non-null   bool
#  15  restecg_2  1025 non-null   bool
#  16  slope_0    1025 non-null   bool
#  17  slope_1    1025 non-null   bool
#  18  slope_2    1025 non-null   bool
#  19  ca_0       1025 non-null   bool
# ...

# %% [markdown]
# # **EDA and Visualizations**

# %%
print(df_encoded['target'].value_counts(normalize=True)*100)
# Out:
# target
# 1    51.317073
# 0    48.682927
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='target',data=df_encoded)
plt.title("Normal Distrubition for target")
# Out:
# Text(0.5, 1.0, 'Normal Distrubition for target')

# %%
numerical_col=('age','trestbps','chol','thalach')

for feature in numerical_col:
  plt.figure(figsize=(6,3))
  sns.histplot(data=df_encoded,x=feature,kde=True)
  plt.title(f'Distribution of {feature}')

# %%
for feature in numerical_col:
  plt.figure(figsize=(6,3))
  sns.boxplot(data=df_encoded,x=feature,)
  plt.title(f'Boxplot of {feature}')

# %%
categorical_features = ['sex', 'cp', 'fbs', 'restecg']

for feature in categorical_col :
  plt.figure(figsize=(6,3))
  sns.countplot(x=feature, data=df)
  plt.title(f"Count of the distruibtion {feature}")
  plt.show

# %%
for feature in numerical_col:
    plt.figure(figsize=(6,3))
    sns.boxplot(x='target', y=feature, data=df)
    plt.title(f'{feature} by Target Class')
    plt.show()

# %%
for feature in categorical_col:
    plt.figure(figsize=(6,3))
    sns.boxplot(x='target', y=feature, data=df)
    plt.title(f'{feature} by Target Class')
    plt.show()

# %%
categorical_features = ['sex', 'cp', 'fbs', 'restecg']

for feature in categorical_col :
  plt.figure(figsize=(6,3))
  sns.countplot(x=feature, data=df)
  plt.title(f"Count of the distruibtion {feature}")
  plt.show

# %%
df['thal'].value_counts()
# Out:
# thal
# 2    544
# 3    410
# 1     64
# 0      7
# Name: count, dtype: int64

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        1025 non-null   int64
#  1   sex        1025 non-null   int64
#  2   trestbps   1025 non-null   int64
#  3   chol       1025 non-null   int64
#  4   fbs        1025 non-null   int64
#  5   thalach    1025 non-null   int64
#  6   exang      1025 non-null   int64
#  7   oldpeak    1025 non-null   float64
#  8   target     1025 non-null   int64
#  9   cp_0       1025 non-null   bool
#  10  cp_1       1025 non-null   bool
#  11  cp_2       1025 non-null   bool
#  12  cp_3       1025 non-null   bool
#  13  restecg_0  1025 non-null   bool
#  14  restecg_1  1025 non-null   bool
#  15  restecg_2  1025 non-null   bool
#  16  slope_0    1025 non-null   bool
#  17  slope_1    1025 non-null   bool
#  18  slope_2    1025 non-null   bool
#  19  ca_0       1025 non-null   bool
# ...

# %% [markdown]
# # **Train_Test_Split**

# %%
X=df_encoded.drop('target',axis=1)
Y=df_encoded['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # **Model Selection**

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression(max_iter=1000)

# %% [markdown]
# # **Model Train**

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
Y_pred=model.predict(X_test)

# %% [markdown]
# # **Evaluation**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
print("Accuracy:", accuracy_score(Y_test, Y_pred))
print("Precision:", precision_score(Y_test, Y_pred))
print("Recall:", recall_score(Y_test, Y_pred))
print("F1-score:", f1_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8195121951219512
# Precision: 0.7796610169491526
# Recall: 0.8932038834951457
# F1-score: 0.832579185520362

# %%
cm = confusion_matrix(Y_test, Y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[76 26]
#  [11 92]]

# %%
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.75      0.80       102
#            1       0.78      0.89      0.83       103
#
#     accuracy                           0.82       205
#    macro avg       0.83      0.82      0.82       205
# weighted avg       0.83      0.82      0.82       205
